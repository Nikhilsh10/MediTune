# %% [markdown]
# # Day 3: Baseline Evaluation (Base Mistral-7B)
#
# Goal: Measure base Mistral-7B accuracy on PubMedQA test set BEFORE any fine-tuning.

# %%
# !pip install -q datasets transformers peft trl bitsandbytes accelerate wandb evaluate rouge_score -U

# %%
import os
import sys
# Ensure repo root is in path if you cloned it
sys.path.append('/kaggle/working/meditune') # Adjust if necessary

# %%
import json
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from datasets import load_dataset
# from src.evaluate import evaluate_pubmedqa  # Import if running within the repo context

# %%
# Load base model only (no LoRA)
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

model = AutoModelForCausalLM.from_pretrained(
    "mistralai/Mistral-7B-Instruct-v0.3",
    quantization_config=bnb_config,
    device_map="auto",
)
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3")
tokenizer.pad_token = tokenizer.eos_token

# %%
# Ensure src is imported or define evaluate_pubmedqa here directly for Kaggle ease
# results = evaluate_pubmedqa(model, tokenizer, n_samples=500)
print("Ensure you run src.evaluate evaluate_pubmedqa method or define it here.")
